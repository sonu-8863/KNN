# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, accuracy_score, recall_score

# %%
heart = pd.read_csv("heart.csv")  # Read & Load the data

x = heart.drop("target", axis=1) 
y = heart["target"].copy()

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

scaler = StandardScaler()
x_train_set = scaler.fit_transform(x_train)
x_test_set = scaler.transform(x_test)

# %%
# kNN = 3
kNN_Classifier = KNeighborsClassifier(n_neighbors=3)
kNN_Classifier.fit(x_train_set, y_train)
y_pred = kNN_Classifier.predict(x_test_set)

print("recall_score:",recall_score(y_test, y_pred))
print("accuracy_score:", accuracy_score(y_test, y_pred))
print("precision_score:", precision_score(y_test, y_pred))
# Out:
# recall_score: 0.78125
# accuracy_score: 0.8524590163934426
# precision_score: 0.9259259259259259

# %%
# kNN = 5
kNN_Classifier = KNeighborsClassifier(n_neighbors=5)
kNN_Classifier.fit(x_train_set, y_train)
y_pred = kNN_Classifier.predict(x_test_set)

print("recall_score:",recall_score(y_test, y_pred))
print("accuracy_score:", accuracy_score(y_test, y_pred))
print("precision_score:", precision_score(y_test, y_pred))
# Out:
# recall_score: 0.875
# accuracy_score: 0.9016393442622951
# precision_score: 0.9333333333333333

# %%
# kNN = 7
kNN_Classifier = KNeighborsClassifier(n_neighbors=7)
kNN_Classifier.fit(x_train_set, y_train)
y_pred = kNN_Classifier.predict(x_test_set)

print("recall_score:",recall_score(y_test, y_pred))
print("accuracy_score:", accuracy_score(y_test, y_pred))
print("precision_score:", precision_score(y_test, y_pred))
# Out:
# recall_score: 0.90625
# accuracy_score: 0.9180327868852459
# precision_score: 0.9354838709677419

# %%
# Cross Validation for HyperParameter Turing
from sklearn.model_selection import GridSearchCV

classifeir = KNeighborsClassifier()
prama_grid = {"n_neighbors": [3,5,7,9]}
cross_validation = GridSearchCV(
    classifeir,
    prama_grid,
    cv=5,
    scoring = "recall"
)

cross_validation.fit(x_train_set,y_train)
y_pred = cross_validation.predict(x_test_set)
print("recall_score:",recall_score(y_test, y_pred))
print("accuracy_score:", accuracy_score(y_test, y_pred))
print("precision_score:", precision_score(y_test, y_pred))

res = pd.DataFrame(cross_validation.cv_results_)
print(res[["param_n_neighbors","mean_test_score"]])
print(cross_validation.best_params_)
# Out:
# recall_score: 0.90625
# accuracy_score: 0.9180327868852459
# precision_score: 0.9354838709677419
#   param_n_neighbors  mean_test_score
# 0                 3         0.864387
# 1                 5         0.857550
# 2                 7         0.871795
# 3                 9         0.856980
# {'n_neighbors': 7}

# %%
# Pipeline 
from sklearn.pipeline import Pipeline

x_train, x_test, y_train, y_test = train_test_split(
    x,y, test_size=0.2, random_state=42)

pipline = Pipeline([
    ("scaler",StandardScaler()),
    ("knn", KNeighborsClassifier())
])

prama_grid = {"knn__n_neighbors": [3,5,7,9]}
cross_validation = GridSearchCV(
    pipline,
    prama_grid,
    cv=5,
    scoring = "recall"
)

cross_validation.fit(x_train,y_train)
y_pred = cross_validation.predict(x_test)
print("recall_score:",recall_score(y_test, y_pred))
print("accuracy_score:", accuracy_score(y_test, y_pred))
print("precision_score:", precision_score(y_test, y_pred))
# Out:
# recall_score: 0.90625
# accuracy_score: 0.9180327868852459
# precision_score: 0.9354838709677419
